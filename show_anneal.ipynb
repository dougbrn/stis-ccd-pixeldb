# %%
import pandas as pd
import numpy as np

# %%
anneal_df = pd.read_csv("anneal_200.csv")

# %%
anneal_df[0:10]
# Each unique row and column combination corresponds to a pixel
# Out:
#    Row  Column  Stability     Sci_Mean   Err_Mean  NaN_Count  Readnoise
# 0    0       0   1.222025    30.850187   8.742004        2.0   6.776667
# 1    0       1   1.794463    18.377115   7.904343        0.0   6.668572
# 2    0       2   1.919204    75.865372  11.355701        1.0   7.313119
# 3    0       3   3.537255    22.821629   8.244081        1.0   6.757134
# 4    0       4   0.582899    39.813313   9.389081        1.0   6.967616
# 5    0       5   0.881280  1170.380859  37.086090        1.0  14.061666
# 6    0       6   9.802744    21.751541   8.192552        1.0   6.800669
# 7    0       7   7.041547    40.333656   9.354438        2.0   6.926795
# 8    0       8  18.605558    32.710663   8.819293        1.0   6.816052
# 9    0       9  17.008673    24.161404   8.239630        1.0   6.701258
